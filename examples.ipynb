# %%
import ograph.ofig as of
import ograph.oplot as op
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Create an Axes3D

# %%
of.fig3()
op.annotate("Title", "x", "y", "z")

plt.show()

# %% [markdown]
# Plot lines, functions, and scatter points.

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# Plot a line that connects [0,0,0] and [0,0,10*np.pi]
ax.plot3D([0,0], [0,0], [0,10*np.pi])

# Plot a spiral
t = np.arange(0, 10*np.pi, np.pi/50)
x = np.sin(t)
y = np.cos(t)
ax.plot3D(x, y, t)

# Plot scatter points around the spiral with randomly offsets
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter(xdata, ydata, zdata, color="grey")

plt.show()

# %% [markdown]
# Contour plots
# Use `plot_wireframe` for wireframe plots, and `plot_surface` for surface plots.

# %%
def himmelblau(x, y):
    return (x ** 2 + y - 11) ** 2 + (x + y ** 2 - 7) ** 2
of.fig3()
op.surface(himmelblau, (-5,5), (-5,5), alpha=0.5)
plt.show()

# %%
def himmelblau(x, y):
    return (x ** 2 + y - 11) ** 2 + (x + y ** 2 - 7) ** 2
of.fig3()
op.wireframe(himmelblau, (-5,5), (-5,5), alpha=0.5)
plt.show()

# %%
of.fig3()
op.contour(himmelblau, (-5,5), (-5,5), levels=100, alpha=0.5)
plt.show()

# %%
from scipy.spatial import ConvexHull, distance #type: ignore
fig = plt.figure()
ax = plt.axes()
op.chull(op.unit_square)

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
op.chull(op.unit_cube)

# %%
transform = np.array([
    [2,0,0],
    [0,1,0],
    [0,3,1]
])

source = op.unit_cube.T

new_unit = transform.dot(source).T
# np.matmul(transform, source)
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.view_init(10, 120)
ax.set_zlabel("z", fontname = 'PT Serif')
op.annotate("", "x", "y", "z")
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
ax.set_xlim3d(-0.5, 1.5)
ax.set_zlim3d(0, 1.5)
for side in ['top','right','bottom','left']:
    ax.spines[side].set_visible(False)
ax.tick_params(axis='both',which='both',labelbottom=False,bottom=False,left=False)
ax.set_yticks([min(y),max(y)]) 


op.chull(op.unit_cube)
op.chull(new_unit)

# %% [markdown]
# Plot an arrow with `oplot.arrow`.

# %%
of.fig3()
op.arrow((0,0,0),
         (1,1,1))
plt.show()

# %%
from ograph.ofunc import himmelblau

of.fig2()
op.contour(himmelblau, (-6, 6), (-6, 6), cmap="Spectral", colorbar=False)
plt.show()

# %%
of.fig3()
op.surface(himmelblau, (-5, 5), (-5, 5), cmap="Spectral", colorbar=False)
plt.show()
# Out:
# <div id='dc9f3c52-e80b-4aea-8b36-384cff1c0e1d'></div>

# %%
def identity(x, y):
    return x + y

# %%
xs = [0.1, 0.2,]
ys = [4, 5, 6]

import numpy as np
# xsi, ysi = np.meshgrid(xs, ys)
# identity(xsi, ysi)

# %%
kk = np.empty(shape=(len(ys), len(xs)))
for i, x in enumerate(xs):
    for j, y in enumerate(ys):
        kk[j][j] = identity(x, y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 4
#       2 for i, x in enumerate(xs):
#       3     for j, y in enumerate(ys):
# ----> 4         kk[j][j] = identity(x, y)
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
# Out:
# array([[4.1, 4.2],
#        [5.1, 5.2],
#        [6.1, 6.2]])
